# %% [markdown]
# # Teste de Hipóteses

# %% [markdown]
# ## **Introdução**
#
# É uma técnica estatística que nos auxilia a tomar decisões sobre uma ou mais populações baseado na informação obtida de uma amostra.
#
# Permite verificar se os dados amostrais trazem evidência que apoiem ou não uma hipótese estatística formulada.
#
# Ao tentarmos tomar decisões, é conveniente a formulação de suposições ou de conjeturas sobre as populações de interesse, que, em geral, consistem em considerações sobre os parâmetros (μ,σ2,p).
#
# Essas suposições, que podem ser ou não verdadeiras, são denominadas de **Hipóteses Estatísticas.**
#
# Em situações práticas o interesse da pessoa pesquisadora é verificar a veracidade sobre um ou mais parâmetros populacionais (μ,σ2,p) ou sobre a distribuição de uma variável aleatória.
#
# **Exemplos:**
#
#         * A produtividade média soja no estado (SP) é de 2500 kg/ha;
#         * A propaganda produz efeito positivo nas vendas de sabonetes;
#
# Um dos primeiros trabalhos sobre testes foi publicado em 1710 (John Arbuthnot).

# %% [markdown]
# ## **Hipóteses Estatísticas**

# %% [markdown]
# **Teste de hipóteses**
#
# O teste de hipóteses fornecem ferramentas que nos permitem rejeitar ou não rejeitar uma hipótese estatística através de evidencia fornecida pela amostra.
#
# **Exemplo:**
#
# Uma pessoa pesquisadora quer testar a hipótese de que a proporção de estudantes que passam em um certo exame é de *𝑝 =* 0.70.
#
# O experimento consiste em observar uma amostra aleatória de estudantes que fizeram o exame. Suponha que *𝑛 =* 150 estudantes foram testados e 105 deles passaram no exame. Dessa forma, foi estimada uma proporção de *𝑝^ =* 0.70 a partir da amostra.
#
# **Formulando as Hipósteses**:
#
# 1. Hipótese Nula (H₀): 𝑝 = 0.70 -> H₀ é uma afirmação sobre a população que estamos tentando contestar.
#
# 2. Hipótese Alternativa (H₁): 𝑝 ≠ 0.70 -> H₁ é uma afirmação que buscamos confirmar, que é o contrário da hipótese nula.
#
# A hipótese nula (H₀) é a afirmação de que a proporção de estudantes que passam no exame é 70%.
#
# A hipótese alternativa (H₁) é a afirmação de que a proporção de estudantes que passam no exame é diferente de 70%.
#
# Podemos ainda especificar a hipótese alternativa (H₁) como: < ou > além da diferença ≠.
#
# **Sempre estabeleceremos a hipótese nula H0 como uma afirmação de igualdade.**

# %% [markdown]
# ### Desafio:
#
# <br>
#
# -> **Formular dois exemplos de Teste de Hipóteses**
#
#
# </br>

# %% [markdown]
# **Exemplo Raquel:**
#
# *Exemplo:* O nível de satisfação de serviços públicos é igual na Favela do Jacarezinho ou no bairro Maria da Graça.
#
# **Hipótese Nula (H0)**: Não há diferença no nível de satisfação nos serviços.
#
# **Hipótese Alternativa (H1):** Há diferença no nível de satisfação nos serviços.

# %% [markdown]
# **Exemplo Ellen**:
#
# *Exemplo*: Existe igualdade de genêro entre as pessoas atletas na Olimpíadas de Paris 2024.
#
# **Hipótese Nula (H0):** Há igualdade de genêro entre as pessoas atletas.
#
# **Hipótese Alternativa (H1):** Não há igualdade de genêro entre as pessoas atletas.

# %% [markdown]
# **Exemplo Danda**:
#
# *Exemplo*: Identificar se o encarcenamento em massa da população negra no Brasil é maior que a população branca em infrações semelhantes.
#
# **Hipótese Nula (H0):** Há um encarcenamento da população negra no Brasil maior que a população branca em infrações semelhantes.
#
# **Hipótese Alternativa (H1):** Não há um encarcenamento da população negra no Brasil maior que a população branca em infrações semelhantes.

# %% [markdown]
# **Exemplo Thaís**:
#
# *Exemplo*: Saber se uma pessoa candidata tem a possibilidade de ganhar a eleição. Foram entrevistadas 200 pessoas eleitoras, sendo que 130 dizeram que votariam na pessoa candidata A.
#
# **Hipótese Nula (H0):** Há possibilidade de 65% das pessoas eleitoras votarem na pessoa candidata A.
#
# **Hipótese Alternativa (H1):** Há possibilidade de ser menor que 65% de pessoas eleitoras votarem na pessoa candidata A.

# %% [markdown]
# ## **Determinar o p-valor**
#
# O p-valor é uma medida utilizada em testes de hipóteses estatísticas para ajudar a determinar a significância dos resultados obtidos. Ele representa a probabilidade de se obter um resultado tão extremo (ou mais extremo) quanto o observado na amostra, assumindo que a hipótese nula (H₀) seja verdadeira. Portanto, o valor-p é um indicador que nos ajuda a entender se a hipótese nula pode ou não ser rejeitada com base nos dados coletados.
#
# **Passos para Comparação do p-valor com α**
#
# Comparar o p-valor com o nível de significância (𝛼) é um passo crucial no processo de teste de hipóteses estatísticas.
#
# Vamos detalhar esse processo:
#
#
# **1. Definir o Nível de Significância (α):**
#
#
#   * O nível de significância (𝛼) é o limite máximo de probabilidade de cometer um erro do tipo I (rejeitar a hipótese nula quando ela é verdadeira) que a pessoa pesquisadora está disposto a aceitar. Comumente, valores de 𝛼 são 0.01, 0.05, ou 0.10.
#
#   * Por exemplo, α = 0.05 significa que a pessoa pesquisadora está disposto a aceitar uma chance de 5% de cometer um erro do tipo I.
#
# **2. Calcular o p-valor:**
#
# * O p-valor é a probabilidade de observar uma estatística de teste tão extrema quanto (ou mais extrema que) a observada, assumindo que a hipótese nula é verdadeira.
# * O cálculo do p-valor depende da distribuição de probabilidade específica usada no teste (normal, t-student, qui-quadrado, etc.).
#
# **3. Comparar o p-valor com α:**
#
# * Se 𝑝 ≤ 𝛼:
#         * Rejeitamos a hipótese nula (H₀).
#         * A evidência contra H₀ é forte o suficiente para concluir que é improvável que o resultado observado tenha ocorrido por acaso sob H₀.
#
# * Se 𝑝 > 𝛼:
#         * Não rejeitamos a hipótese nula (H₀).
#         * Não há evidências suficientes para concluir que o resultado observado é inconsistente com H₀.
#
# ### **Tipos de Erros**:
#
# Na tomada de decisão, dado algum critério, podemos obviamente estar comentendo algum erro, chamaremos esses erros de erro do tipo I e II.
#
# **Erro do Tipo I**: Rejeitar a hipótese nula H0 quando ela é verdadeira.
#
# **Erro do Tipo II**: Não Rejeitar a hipótese nula H0  quando ela é falsa.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Tipos de Testes de Hipóteses**
#
# Existem vários tipos de testes de hipóteses, incluindo:
#
# **Testes Unilaterais:** Este processo consiste em realizar um teste estatístico para verificar se a diferença entre um grupo específico e o grupo total é maior ou menor que um valor escolhido. Esse teste é comum em estudos científicos e de pesquisa para verificar se há uma diferença importante entre dois grupos de dados.
#
# **Testes Bilaterais:** São técnicas de estatística usadas quando queremos verificar se a diferença entre as médias de um grupo e de uma população é bem diferente de um valor que já decidimos antes. Isso é comumente usado em pesquisas científicas e outros estudos para testar ideias e conseguir resultados.
#
# **Testes Paramétricos:** Esses testes são feitos presumindo que os dados seguem uma distribuição normal. Essa suposição é importante porque nos permite usar várias técnicas estatísticas que podem nos dar informações úteis sobre os dados. Assim, antes de fazer um teste paramétrico, é muito importante verificar se os dados são normais.
#
# **Testes Não Paramétricos:** São testes estatísticos especiais que não precisam considerar que os dados seguem uma distribuição normal. Isso os torna úteis e adaptáveis quando não podemos garantir essa suposição.

# %% [markdown]
# ### **Exemplo do caso mencionado acima**
#
# Vamos conduzir um teste de hipótese para determinar se a evidência da amostra refuta a hipótese nula.
#
# ![image.png](data:image/png;base64,...)
#
# **Conclusão:**
#
# Não há evidências suficientes para refutar a hipótese de que a proporção de estudantes que passam no exame é 70%. Portanto, não rejeitamos a hipótese postulada anteriormente.
#
#
# **Valor 1.96**
#
# O valor de 1.96 é um valor crítico muito utilizado em estatística, especialmente no contexto de testes de hipóteses e intervalos de confiança para uma distribuição normal. Vamos detalhar o que ele representa e como é utilizado.
#
# **1. Distribuição Normal Padrão:**
#
# * A distribuição normal padrão é uma distribuição normal com média 0 e desvio padrão 1.
# * Em uma distribuição normal padrão, 95% dos valores se encontram dentro de 1.96 desvios padrão da média (0), ou seja, entre -1.96 e 1.96.
#
# **2. Intervalo de confiança de 95%:**
#
# * Quando construímos um intervalo de confiança de 95% para a média de uma população, estamos dizendo que, se coletássemos muitas amostras e construíssemos intervalos de confiança da mesma forma, aproximadamente 95% desses intervalos conteriam a verdadeira média populacional.
#
# * O valor 1.96 é o z-score que corresponde ao percentil 97.5 da distribuição normal padrão. Isso significa que 2.5% da área sob a curva está à direita de 1.96 e 2.5% está à esquerda de -1.96. Juntos, isso cobre 95% da área central.
#
# **3. Teste de Hipóteses:**
#
# * No contexto de um teste de hipóteses bicaudal com um nível de significância de 𝛼 = 0.05, os valores críticos são -1.96 e 1.96.
# * Se a estatística de teste z está fora do intervalo [−1.96,1.96], rejeitamos a hipótese nula (H₀). Isso ocorre porque os valores fora desse intervalo estão na cauda de 2.5% de cada lado da distribuição, totalizando um nível de significância de 5%.
#
# ![image.png](data:image/png;base64,...)
#
# * As áreas em vermelho representam as regiões além dos valores críticos de −1.96 e 1.96.
#
# * Cada uma dessas áreas cobre 2.5% da distribuição, totalizando 5% para ambas as caudas.
#
# * Essas áreas são utilizadas para testes de hipóteses e intervalos de confiança, indicando as regiões onde a hipótese nula seria rejeitada em um teste bicaudal com um nível de significância de 0.05.
#
#
# Os valores negativos no eixo X do gráfico da distribuição normal padrão têm um significado importante em estatística. Veremos abaixo:
#
# **Distribuição Normal Padrão**
#
# 1. Simetria:
#
# * A distribuição normal padrão é simétrica em torno da média, que é 0.
#
# * Isso significa que os valores à esquerda da média (negativos) têm a mesma probabilidade e comportamento que os valores à direita da média (positivos).
#
# **Valores de Z:**
#
# * Os valores no eixo X são chamados de valores z ou z-scores.
# * Um z-score representa o número de desvios padrão que um dado ponto está distante da média da distribuição.
# * Valores negativos indicam que o ponto está à esquerda da média, enquanto valores positivos indicam que o ponto está à direita da média.

# %% [markdown]
# **Interpretação dos Valores Negativos**
#
# 1. Área Crítica:
#
# * Em testes de hipóteses bicaudais, consideramos áreas críticas em ambos os lados da distribuição para detectar desvios significativos tanto para menos quanto para mais.
# * Por isso, usamos tanto valores críticos negativos quanto positivos (por exemplo, −1.96 e 1.96).
#
# 2. Probabilidade:
#
# * A área sob a curva à esquerda de qualquer valor negativo de z representa a probabilidade acumulada de obter um valor menor que aquele z-score.
#
# * Da mesma forma, a área à direita de qualquer valor positivo de z representa a probabilidade acumulada de obter um valor maior que aquele z-score.
#
# **Exemplo Prático**
#
# Se estamos testando a hipótese de que a média de uma população é 0, e obtemos um z-score de −2.5, isso indica que o valor observado está 2.5 desvios padrão abaixo da média. Se o z-score fosse 2.5, o valor observado estaria 2.5 desvios padrão acima da média.
#
# **Resumo**:
#
# Os valores negativos no eixo X do gráfico da distribuição normal padrão são essenciais para representar a simetria da distribuição e para calcular probabilidades e áreas críticas em ambos os lados da média. Eles nos ajudam a compreender como os dados se distribuem em relação à média e a tomar decisões estatísticas informadas.

# %% [markdown]
# # Alguns dos testes de hipóteses mais comuns:
#
# **Teste z:**
#
# Usado para grandes amostras (n > 30) quando a distribuição da amostra é aproximadamente normal. Pode ser usado para testar a média de uma única amostra ou para comparar médias de duas amostras independentes.
#
# **Teste t de Student:**
#
# * **Teste t para uma amostra:** Verifica se a média de uma única amostra é significativamente diferente de um valor específico.
#
# * **Teste t para duas amostras independentes:** Compara as médias de duas amostras independentes para verificar se são significativamente diferentes.
#
# * **Teste t pareado:** Compara as médias de duas amostras relacionadas (ou emparelhadas) para verificar se são significativamente diferentes.
#
#
# **Teste qui-quadrado (χ²):**
#
# * **Teste de independência:** Avalia se duas variáveis categóricas são independentes ou associadas.
#
# * **Teste de bondade de ajuste:** Verifica se uma distribuição observada difere significativamente de uma distribuição esperada.
#
# **Análise de Variância (ANOVA):**
#
# Compara as médias de três ou mais grupos para verificar se pelo menos um grupo é significativamente diferente dos outros.
#
#
# **Obs:** Cada um desses testes, assim como os outros, tem suas próprias condições de aplicabilidade, que devem ser atendidos para que os resultados sejam válidos.
#
# **Indicação de Material**:
#
# https://github.com/reprograma/on29-python-s13-estatistica-II/tree/main/capitulos/testes

# %% [markdown]
# ## Aplicações Práticas de Testes de Hipóteses
#
# Os testes de hipóteses são amplamente utilizados em diversos campos, incluindo:
#
# * Saúde: Na área da saúde, os testes de hipóteses são essenciais para avaliar a eficácia de novos medicamentos e tratamentos. Eles são usados para determinar se um novo medicamento ou tratamento é significativamente melhor do que o atualmente disponível.
#
# * Engenharia: No campo da engenharia, eles são frequentemente utilizados para controle de qualidade e otimização de processos. Isso permite que as empresas garantam que seus produtos atendam a padrões rigorosos e que seus processos sejam tão eficientes quanto possível.
#
# * Marketing: No marketing, os testes de hipóteses são usados para testar a eficácia de diferentes campanhas publicitárias e para analisar dados de clientes. Isso pode ajudar as empresas a entender melhor seus clientes e criar campanhas mais eficazes.
#
# * Finanças: Na área de finanças, os testes de hipóteses são usados para analisar investimentos e gerenciar riscos. Isso permite que os investidores tomem decisões informadas e minimizem o risco de perdas financeiras.

# %% [markdown]
# # Como usar Python para esses cálculos...

# %% [markdown]
# Para realizar um **teste z** em Python, podemos usar a biblioteca **statsmodels**, que fornece funções para realizar testes estatísticos, incluindo o **teste z** para uma amostra e para duas amostras independentes. Vamos adaptar o exemplo anterior para realizar um **teste z**.
#
#
# **Teste z para uma amostra**
#
# O objetivo é verificar se a média de uma amostra é significativamente diferente de um valor de referência.
#
#
# **Teste z para duas amostras independentes**
#
# O objetivo é comparar as médias de duas amostras independentes para verificar se são significativamente diferentes.
#
# Vamos implementar esses dois testes.

# %%
# instalação
#!pip install statsmodels

# %% [markdown]
# ### Exemplo de teste de hipóteses:
#
# A hipótese nula (H₀) é a afirmação de que a turma tenha a nota média de 70.
#
# A hipótese alternativa (H₁) é a afirmação de que a turma tenha a nota média diferente de 70.

# %%
from statsmodels.stats.weightstats import ztest
import numpy as np

# Dados da amostra
amostra = np.array([68, 70, 72, 65, 75, 78, 67, 69, 74, 71, 73, 72, 68, 70, 71])
valor_referencia = 70

print(f"Amostra {amostra}")
print(f"Valor Referência: {valor_referencia}")

# %%
# Teste z para uma amostra
z_statistic, p_value = ztest(amostra, value=valor_referencia)
print("Teste z para uma amostra:")
print(f"z-statistic: {z_statistic:.4f}, p-value: {p_value:.4f}")

# %% [markdown]
# **Teste z para uma amostra:**
#
# *ztest(amostra, value=valor_referencia)* compara a média da amostra com o valor_referencia.
#
# *z_statistic* é o valor da estatística z calculada.
#
# *p_value* é o valor p associado ao teste, que nos diz se a diferença observada é estatisticamente significativa.

# %%
# Dados das amostras independentes
amostra1 = np.array([68, 70, 72, 65, 75, 78, 67, 69, 74, 71])
amostra2 = np.array([60, 62, 64, 63, 66, 70, 65, 67, 71, 69])

# Teste z para duas amostras independentes
z_statistic_ind, p_value_ind = ztest(amostra1, amostra2)
print("\nTeste z para duas amostras independentes:")
print(f"z-statistic: {z_statistic_ind:.4f}, p-value: {p_value_ind:.4f}")

# %% [markdown]
# **Teste z para duas amostras independentes:**
#
# *ztest(amostra1, amostra2)* compara as médias de amostra1 e amostra2.
#
# *z_statistic_ind* é o valor da estatística z calculada.
#
# *p_value_ind* é o valor p associado ao teste, que indica se as diferenças entre as duas amostras são estatisticamente significativas.

# %% [markdown]
# **Teste z para uma amostra:**
#
#     z-statistic: 1.0064
#     p-value: 0.3142
#
# Como o valor p é maior que 0.05, não rejeitamos a hipótese nula. Isso significa que não há evidência estatisticamente significativa para afirmar que a média da amostra é diferente de 70.
#
# **Teste z para duas amostras independentes:**
#
#     z-statistic: 3.0772
#     p-value: 0.0021
#
# Como o valor p é menor que 0.05, rejeitamos a hipótese nula. Isso significa que há evidência estatisticamente significativa para afirmar que as médias das duas amostras são diferentes.

# %% [markdown]
# ## Teste T de Stdudent

# %% [markdown]
# Para realizar um **teste t de Student** usando Python, você pode utilizar a biblioteca **scipy**, que contém funções para estatísticas.
#
# Aqui está um exemplo de código que realiza tanto um **teste t** para uma amostra **única** quanto um **teste t** para duas amostras **independentes**:
#
#
# **Teste t para uma amostra**
#
# O objetivo é verificar se a média de uma amostra é significativamente diferente de um valor de referência.
#
# **Teste t para duas amostras independentes**
#
# O objetivo é comparar as médias de duas amostras independentes para verificar se são significativamente diferentes.
#
# **Vamos implementar esses dois testes.**
#
# Suponha que temos uma amostra de pontuações de exame de estudantes e queremos verificar se a média da amostra é significativamente diferente de um valor de referência (por exemplo, 70). Também vamos comparar duas amostras independentes de pontuações de exame de dois grupos diferentes de estudantes.

# %%
import numpy as np
from scipy import stats

# Dados da amostra
amostra_notas = [68, 70, 72, 65, 75, 78, 67, 69, 74, 71, 73, 72, 68, 70, 71]
valor_referencia = 70

# Teste t para uma amostra
t_statistic, p_value = stats.ttest_1samp(amostra_notas, valor_referencia)
print("Teste t para uma amostra:")
print(f"t-statistic: {t_statistic:.4f}, p-value: {p_value:.4f}")

# %% [markdown]
# Este teste verifica se a média da amostra é significativamente diferente de um valor de referência (70 neste caso).
#
# **Teste t para uma amostra:**
#
# *stats.ttest_1samp(amostra, valor_referencia)* compara a média da amostra com o valor_referencia.
#
# *t_statistic* é o valor da estatística *t* calculada.
#
# *p_value* é o valor *p* associado ao teste, que nos diz se a diferença observada é estatisticamente significativa.
#
#
# **Se o valor p (p-value) for menor que um nível de significância comum (por exemplo, 0.05), rejeitamos a hipótese nula (H0) de que a média da amostra é igual ao valor de referência. Caso contrário, não rejeitamos a hipótese nula.**

# %%
# Dados das amostras independentes
amostra1 = [68, 70, 72, 65, 75, 78, 67, 69, 74, 71]
amostra2 = [60, 62, 64, 63, 66, 70, 65, 67, 71, 69]

# Teste t para duas amostras independentes
t_statistic_ind, p_value_ind = stats.ttest_ind(amostra1, amostra2)
print("\nTeste t para duas amostras independentes:")
print(f"t-statistic: {t_statistic_ind:.4f}, p-value: {p_value_ind:.4f}")

# %% [markdown]
# Este teste compara as médias de duas amostras independentes.
#
# **Teste t para duas amostras independentes:**
#
# *stats.ttest_ind(amostra1, amostra2)* compara as médias de amostra1 e amostra2.
#
# *t_statistic_ind* é o valor da estatística *t* calculada.
#
# *p_value_ind* é o valor *p* associado ao teste, que indica se as diferenças entre as duas amostras são estatisticamente significativas.
#
# **Se o valor p (p_value_ind) for menor que um nível de significância comum (por exemplo, 0.05), rejeitamos a hipótese nula (H0) de que as médias das duas amostras são iguais. Caso contrário, não rejeitamos a hipótese nula.**

# %% [markdown]
# **Interpretação dos resultados:***
#
# **Teste t para uma amostra:**
#
#         t-statistic: 1.0064
#         p-value: 0.3313
#
#
# Como o valor p é maior que 0.05, não rejeitamos a hipótese nula. Isso significa que não há evidência estatisticamente significativa para afirmar que a média da amostra é diferente de 70.
#
# **Teste t para duas amostras independentes:**
#
#         t-statistic: 3.0772
#         p-value: 0.0065
#
# Como o valor p é menor que 0.05, rejeitamos a hipótese nula. Isso significa que há evidência estatisticamente significativa para afirmar que as médias das duas amostras são diferentes.
#
# Esses resultados indicam que, para o teste de uma amostra, a média da amostra não difere significativamente do valor de referência (70). No entanto, para o teste de duas amostras independentes, há uma diferença significativa entre as médias das duas amostras.

# %% [markdown]
# # Coleta de dados para o exercício de casa:
#
# Coletar a altura média de cada uma das alunas, incluindo a Professora, Facilitaroa e Monitora.
#
#
# **Exercício: Teste z para Altura Média da Turma**
#
# **Cenário:**
#
# Queremos avaliar se a altura média da turma on35 é significativamente diferente da altura média nacional da população feminina brasileira, que é de 160 cm.
#
# **Objetivo:**
#
#     Verificar se a altura média da turma é significativamente diferente de 160 cm.
#
# Dados da Amostra:
#
#     Altura da turma (em cm): [158, 162, 161, 159, 164, 165, 157, 160, 163, 161, 159, 162, 158, 160, 161]
#
#
# **Perguntas:**
#
#
# Calcule a estatística z e o valor p para verificar se a altura média da turma é significativamente diferente de 160 cm.
#
# **Interprete os resultados:** A altura média da turma é significativamente diferente de 160 cm?
#
# **Hipóteses:**
#
# **Hipótese Nula (H0):**
#
# A hipótese nula é a suposição inicial de que não há diferença significativa entre a média da amostra e o valor de referência.
# No contexto do nosso exemplo:
#
#     H0​: A altura média da turma on 35 é igual à altura média nacional.
#     H0:μ=160
#
# **Hipótese Alternativa (H1):**
#
# A hipótese alternativa é a afirmação que desejamos testar, que sugere que existe uma diferença significativa.
#
# No contexto do nosso exemplo:
#
#       H1​: A altura média dos alunas da turma é diferente da altura média nacional.
#       H1:μ≠160
#
# ### Em outras palavras...
#
# **Hipótese Nula (H0):**
#
# Supõe que não há diferença entre a média da amostra e a média da população (160 cm). A média da altura das alunas da turma é 160 cm.
#
# **Hipótese Alternativa (H1):**
#
# Sugere que há uma diferença entre a média da amostra e a média da população. A média da altura das alunas da turma não é 160 cm.
#
#
# **Teste Bilateral:**
#
# Neste exemplo, utilizamos um teste bilateral (ou de duas caudas), pois estamos verificando se a média da altura da turma é diferente (pode ser maior ou menor) da média nacional, e não apenas se é maior ou menor.

# %%
import numpy as np
from statsmodels.stats.weightstats import ztest

ana = 170
deborah = 164
nelia =168

# Dados da amostra
altura_turma = np.array([ana, deborah, nelia, 157, 160, 157, 163, 170, 167, 174, 160, 169, 158, 161, 168, 162, 167, 167, 165, 170, 170])
media_nacional = 161

# Teste z para uma amostra
z_statistic, p_value = ztest(altura_turma, value=media_nacional)
print("Teste z para uma amostra:")
print(f"z-statistic: {z_statistic:.4f}, p-value: {p_value:.4f}")

# %% [markdown]
# **Respostas Esperadas:**
#
# Teste z para uma amostra:
#
#
#     * Se o valor p for menor que 0.05, a altura média da turma é significativamente diferente de 161 cm.

# %% [markdown]
# A interpretação do valor do teste z para uma amostra, com uma estatística z de 1.1282 e um valor p de 0.2593, é a seguinte:
#
# **Interpretação:**
#
# **Estatística z (z-statistic): 3.8156**
#
#   A estatística z indica quantos desvios padrão a média da amostra está distante da média de referência (161 cm) sob a hipótese nula.
#   Um valor positivo da estatística z sugere que a média da amostra está acima da média de referência, mas precisamos do valor p para determinar a significância.
#
# **Valor p (p-value): 0.0001**
#
#   O valor p representa a probabilidade de observar um valor da estatística z tão extremo ou mais extremo do que o valor observado, assumindo que a hipótese nula é verdadeira.
#   Neste caso, um valor p de 0.0001 significa que há aproximadamente 0,01% de chance de obter a média da amostra observada (ou uma mais extrema) se a média real da população fosse de fato 161 cm.
#
# **Conclusão:**
#
# Nível de Significância: Um nível de significância comum usado em testes estatísticos é 0.05 (ou 5%). Se o valor p for menor que 0.05, rejeitamos a hipótese nula.
# Neste caso: O valor p (0.0001) é menor que 0.05. Portanto, rejeitamos a hipótese nula.
#
# **Interpretação Final:**
#
# A altura média da amostra de alturas da turma é significativamente diferente de 161 cm. Em outras palavras, há evidências estatisticamente significativas para afirmar que a altura média da turma difere da altura média nacional de 161 cm.

# %% [markdown]
# # Outro exemplo:
#
# **Exemplo Raquel:**
#
# *Exemplo:* O nível de satisfação de serviços públicos é igual na Favela do Jacarezinho ou no bairro Maria da Graça.
#
# **Hipótese Nula (H0)**: Não há diferença no nível de satisfação nos serviços.
#
# **Hipótese Alternativa (H1):** Há diferença no nível de satisfação nos serviços.

# %%
import random

amostra_jacarezinho = list(np.random.randint(low = 0,high=10, size=100))
amostra_maria_graca = list(np.random.randint(low = 0,high=10, size=100))

# %%
# Teste z para duas amostras independentes
z_statistic_ind, p_value_ind = ztest(amostra_jacarezinho, amostra_maria_graca)
print("\nTeste z para duas amostras independentes:")
print(f"z-statistic: {z_statistic_ind:.4f}, p-value: {p_value_ind:.4f}")

# %% [markdown]
# **Interpretação**:
#
# Não há diferença entre o nível de satisfação de serviços públicos entre os bairros. Não rejeitamos a hipótese nula (H0), pois há evidências estatisticamente significativas para afirmar que o nível de satisfação de serviços públicos é igual para ambos os bairros.

# %% [markdown]
# # Revisão da aula

# %% [markdown]
# ## Cenário do teste de hipóteses:
#
# Queremos testar se um novo método de ensino melhora o desempenho dos estudantes em comparação com o método tradicional já utilizado.
#
# **Passo a passo:**
#
# 1. Definir as hipóteses:
#
#     **Hipótese nula (H0​):** O novo método de ensino não tem efeito (a média das notas dos estudantes com o novo método é igual à média das notas dos estudantes com o método tradicional).
#
#     **Hipótese alternativa (H1​):** O novo método de ensino tem efeito (a média das notas dos estudantes com o novo método é diferente da média das notas dos estudantes com o método tradicional).
#
# 2. Coletar dados:
#
#     **Grupo 1 (método tradicional):** uma amostra de 40 estudantes.
#
#     **Grupo 2 (novo método):** uma amostra de 40 estudantes.
#
# 3. Calcular a média e o desvio padrão dos dois grupos.
#
# 4. Calcular o Z score e o p-valor.
#
# 5. Tomar uma decisão com base no p-valor e no nível de significância (α).

# %%
# bibliotecas necessárias:
import numpy as np
from statsmodels.stats.weightstats import ztest

# %%
# Gerar dados simulados
np.random.seed(42)  # Para reprodutibilidade

# %%
# Amostras do método tradicional (grupo controle)
tradicional = np.random.normal(loc=70, scale=12, size=40)  # Média 70, desvio padrão 12
tradicional
# Out:
# array([67.36393735, 74.28535086, 87.73472854, 63.78075738, 60.29807677,
#        63.97891548, 80.98482541, 73.94501332, 63.64287755, 76.1592092 ,
#        71.16493059, 81.62373989, 61.57536287, 66.06805424, 65.29470216,
#        52.43782062, 73.55344332, 73.13266327, 70.06136148, 67.1849544 ,
#        53.0155511 , 64.95225613, 65.8874258 , 60.37267277, 68.06457146,
#        74.84861028, 92.63423081, 72.09493375, 73.09060469, 69.10664901,
#        46.97474542, 69.68183349, 70.72276252, 99.55890535, 67.69166842,
#        73.61856811, 69.58345876, 55.97586355, 83.71387377, 79.02319639])

# %%
# Amostras do novo método (grupo teste)
novo_metodo = np.random.normal(loc=75, scale=12, size=40)  # Média 75, desvio padrão 12
novo_metodo
# Out:
# array([ 84.49238336,  64.08735054,  91.83353173,  58.17778725,
#         82.04228513, 101.28546751,  63.1135641 ,  68.20442724,
#         76.19581638,  68.95829215,  56.39203883,  75.8227557 ,
#         62.25235544,  80.68310917,  63.96690919,  93.59921286,
#         65.60096049,  71.13526181,  84.76220661,  60.2296282 ,
#         77.72951922,  90.68571305,  55.71020119,  77.2156063 ,
#         78.11859353,  84.38187446,  60.15659147,  59.15452064,
#         81.26329879,  78.56381608,  78.0059142 ,  79.15737851,
#         66.83970334,  77.78704437,  78.51686968,  66.42778298,
#         97.38929413,  80.68599505,  60.70435803,  82.8786433 ])

# %%
# Calcular médias e desvios padrão
mean_tradicional = np.mean(tradicional)
mean_novo_metodo = np.mean(novo_metodo)
std_tradicional = np.std(tradicional, ddof=1)
std_novo_metodo = np.std(novo_metodo, ddof=1)

# %%
# Realizar o teste z
z_score, p_value = ztest(novo_metodo, tradicional)

# Nível de significância
alpha = 0.05

print(f"Média do grupo tradicional: {mean_tradicional:.2f}")
print(f"Média do grupo novo método: {mean_novo_metodo:.2f}")
print(f"Desvio padrão do grupo tradicional: {std_tradicional:.2f}")
print(f"Desvio padrão do grupo novo método: {std_novo_metodo:.2f}")
print(f"Z score: {z_score:.2f}")
print(f"P-valor: {p_value:.4f}")

if p_value < alpha:
    print("Rejeitamos a hipótese nula. Há evidências de que o novo método de ensino tem efeito.")
else:
    print("Não rejeitamos a hipótese nula. Não há evidências de que o novo método de ensino tem efeito.")
# Out:
# Média do grupo tradicional: 70.12
# Média do grupo novo método: 74.61
# Desvio padrão do grupo tradicional: 10.35
# Desvio padrão do grupo novo método: 11.77
# Z score: 1.81
# P-valor: 0.0703
# Não rejeitamos a hipótese nula. Não há evidências de que o novo método de ensino tem efeito.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parâmetros da distribuição normal padrão
mu = 0
sigma = 1

# Valores do eixo x
x = np.linspace(-4, 4, 1000)

# Função densidade de probabilidade (PDF) da distribuição normal padrão
pdf = norm.pdf(x, mu, sigma)

# Z score que queremos destacar
z_score

# Gerar o gráfico
plt.figure(figsize=(7, 5))

# Plotar a distribuição normal padrão
plt.plot(x, pdf, label='Distribuição Normal Padrão')

# Destacar o Z score
plt.fill_between(x, 0, pdf, where=(x >= z_score), color='red', alpha=0.5, label=f'Z score = {z_score}')
plt.axvline(z_score, color='red', linestyle='--')

# Adicionar títulos e legendas
plt.title('Distribuição Normal Padrão com Z score Destacado')
plt.xlabel('Z score')
plt.ylabel('Densidade de Probabilidade')
plt.legend()

# Mostrar o gráfico
plt.show()

# %% [markdown]
# Um Z score de 1.81 indica que a média do grupo que recebeu o novo método de ensino está 1.81 desvios padrão acima da média do grupo que recebeu o método tradicional. Isso sugere uma diferença substancial entre os dois grupos.
#
# **Probabilidade e Área Sob a Curva:**
#
# Na distribuição normal padrão, um Z score de 1.81 corresponde a uma área acumulada à esquerda muito próxima de 1 (ou seja, quase 100%). Para ser mais preciso, a área acumulada à esquerda de Z = 1.81 é aproximadamente 0.96485. Isso significa que a probabilidade de obter um valor de Z score igual ou menor que 1.81 é 96.49%.

# %% [markdown]
# # Novo Exemplo:
#
# Queremos saber se a nova ação de mkt fez efeito no valor do ticket médio de compra em uma loja virtual de roupas.
#
#  **Hipótese nula (H0​):** Há um aumento no ticket médio.
#
# **Hipótese alternativa (H1​):** Não há um aumento no ticket médio.

# %%
# Dados da amostra
amostra = [125, 100, 90, 289, 360, 50, 30, 69, 15]
valor_referencia = [116]

# %%
# Realizar o teste z
z_score, p_value = ztest(amostra, valor_referencia)

# Nível de significância
alpha = 0.05

print(f"Média do grupo tradicional: {mean_tradicional:.2f}")
print(f"Média do grupo novo método: {mean_novo_metodo:.2f}")
print(f"Desvio padrão do grupo tradicional: {std_tradicional:.2f}")
print(f"Desvio padrão do grupo novo método: {std_novo_metodo:.2f}")
print(f"Z score: {z_score:.2f}")
print(f"P-valor: {p_value:.4f}")

if p_value < alpha:
    print("Rejeitamos a hipótese nula. Não há evidências de que a ação de mkt teve efeito nas vendas.")
else:
    print("Não rejeitamos a hipótese nula. Há evidências de que a ação de mkt teve efeito nas vendas.")
# Out:
# Média do grupo tradicional: 70.12
# Média do grupo novo método: 74.61
# Desvio padrão do grupo tradicional: 10.35
# Desvio padrão do grupo novo método: 11.77
# Z score: 0.07
# P-valor: 0.9408
# Não rejeitamos a hipótese nula. Há evidências de que a ação de mkt teve efeito nas vendas.
